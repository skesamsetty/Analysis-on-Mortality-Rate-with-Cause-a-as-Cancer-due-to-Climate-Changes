# %%
import pandas as pd

# Dependencies and Setup
import matplotlib.pyplot as plt

# %%
mortality_rate = pd.read_csv("csv-1.csv")
temperature_rate = pd.read_csv("model_state.csv")

# %%
cancer_rate = mortality_rate.loc[mortality_rate["Cause Name"]=="Cancer"]
cancer_rate = cancer_rate.rename(columns={"Year":"year"})
cancer_rate
# Out:
#       year                 113 Cause Name Cause Name    State  Deaths  \
# 1923  2016  Malignant neoplasms (C00-C97)     Cancer  Alabama   10419
# 1924  2015  Malignant neoplasms (C00-C97)     Cancer  Alabama   10354
# 1925  2014  Malignant neoplasms (C00-C97)     Cancer  Alabama   10286
# 1926  2013  Malignant neoplasms (C00-C97)     Cancer  Alabama   10328
# 1927  2012  Malignant neoplasms (C00-C97)     Cancer  Alabama   10276
# ...    ...                            ...        ...      ...     ...
# 2854  2003  Malignant neoplasms (C00-C97)     Cancer  Wyoming     943
# 2855  2002  Malignant neoplasms (C00-C97)     Cancer  Wyoming     859
# 2856  2001  Malignant neoplasms (C00-C97)     Cancer  Wyoming     923
# 2857  2000  Malignant neoplasms (C00-C97)     Cancer  Wyoming     868
# 2858  1999  Malignant neoplasms (C00-C97)     Cancer  Wyoming     899
#
#       Age-adjusted Death Rate
# 1923                    174.0
# 1924                    175.6
# 1925                    177.6
# 1926                    182.2
# 1927                    185.2
# ...                       ...
# 2854                    188.9
# 2855                    177.1
# 2856                    194.0
# 2857                    185.5
# 2858                    195.1
#
# [936 rows x 6 columns]

# %%
cancer_rate = mortality_rate.loc[mortality_rate["Cause Name"]=="Cancer"]
cancer_rate = cancer_rate.rename(columns={"Year":"year"})
cancer_rate
# Out:
#       year                 113 Cause Name Cause Name    State  Deaths  \
# 1923  2016  Malignant neoplasms (C00-C97)     Cancer  Alabama   10419
# 1924  2015  Malignant neoplasms (C00-C97)     Cancer  Alabama   10354
# 1925  2014  Malignant neoplasms (C00-C97)     Cancer  Alabama   10286
# 1926  2013  Malignant neoplasms (C00-C97)     Cancer  Alabama   10328
# 1927  2012  Malignant neoplasms (C00-C97)     Cancer  Alabama   10276
# ...    ...                            ...        ...      ...     ...
# 2854  2003  Malignant neoplasms (C00-C97)     Cancer  Wyoming     943
# 2855  2002  Malignant neoplasms (C00-C97)     Cancer  Wyoming     859
# 2856  2001  Malignant neoplasms (C00-C97)     Cancer  Wyoming     923
# 2857  2000  Malignant neoplasms (C00-C97)     Cancer  Wyoming     868
# 2858  1999  Malignant neoplasms (C00-C97)     Cancer  Wyoming     899
#
#       Age-adjusted Death Rate
# 1923                    174.0
# 1924                    175.6
# 1925                    177.6
# 1926                    182.2
# 1927                    185.2
# ...                       ...
# 2854                    188.9
# 2855                    177.1
# 2856                    194.0
# 2857                    185.5
# 2858                    195.1
#
# [936 rows x 6 columns]

# %%
cancer_df = cancer_rate.loc[(cancer_rate["year"]>1999) & (cancer_rate["State"]=="Colorado")]
cancer_df
# Out:
#       year                 113 Cause Name Cause Name     State  Deaths  \
# 2013  2016  Malignant neoplasms (C00-C97)     Cancer  Colorado    7928
# 2014  2015  Malignant neoplasms (C00-C97)     Cancer  Colorado    7604
# 2015  2014  Malignant neoplasms (C00-C97)     Cancer  Colorado    7405
# 2016  2013  Malignant neoplasms (C00-C97)     Cancer  Colorado    7357
# 2017  2012  Malignant neoplasms (C00-C97)     Cancer  Colorado    7306
# 2018  2011  Malignant neoplasms (C00-C97)     Cancer  Colorado    7051
# 2019  2010  Malignant neoplasms (C00-C97)     Cancer  Colorado    7035
# 2020  2009  Malignant neoplasms (C00-C97)     Cancer  Colorado    6950
# 2021  2008  Malignant neoplasms (C00-C97)     Cancer  Colorado    6719
# 2022  2007  Malignant neoplasms (C00-C97)     Cancer  Colorado    6617
# 2023  2006  Malignant neoplasms (C00-C97)     Cancer  Colorado    6550
# 2024  2005  Malignant neoplasms (C00-C97)     Cancer  Colorado    6395
# 2025  2004  Malignant neoplasms (C00-C97)     Cancer  Colorado    6196
# 2026  2003  Malignant neoplasms (C00-C97)     Cancer  Colorado    6417
# 2027  2002  Malignant neoplasms (C00-C97)     Cancer  Colorado    6384
# 2028  2001  Malignant neoplasms (C00-C97)     Cancer  Colorado    6145
# 2029  2000  Malignant neoplasms (C00-C97)     Cancer  Colorado    5922
#
#       Age-adjusted Death Rate
# 2013                    137.1
# 2014                    134.4
# 2015                    136.0
# 2016                    139.2
# 2017                    143.1
# 2018                    143.9
# 2019                    149.5
# 2020                    151.4
# 2021                    150.9
# 2022                    154.1
# 2023                    157.5
# 2024                    159.7
# 2025                    159.4
# 2026                    169.4
# 2027                    173.7
# 2028                    170.9
# 2029                    170.0

# %%
climate_change = pd.read_csv("climdiv_state_year.csv")
climate_df =climate_change.loc[(climate_change["year"]>1999) & (climate_change["year"]<2017) & (climate_change["fips"]==8)]
climate_df
# Out:
#      fips  year       temp     tempc
# 605     8  2000  47.000000  8.333333
# 606     8  2001  46.850000  8.250000
# 607     8  2002  46.083333  7.824074
# 608     8  2003  47.025000  8.347222
# 609     8  2004  45.841667  7.689815
# 610     8  2005  46.766667  8.203704
# 611     8  2006  46.508333  8.060185
# 612     8  2007  46.175000  7.875000
# 613     8  2008  44.941667  7.189815
# 614     8  2009  45.183333  7.324074
# 615     8  2010  46.150000  7.861111
# 616     8  2011  45.433333  7.462963
# 617     8  2012  48.316667  9.064815
# 618     8  2013  45.091667  7.273148
# 619     8  2014  46.058333  7.810185
# 620     8  2015  47.441667  8.578704
# 621     8  2016  47.283333  8.490741

# %%
whole_data = cancer_df.merge(climate_df , how= 'outer', on="year" )
yearly_cancer= whole_data.groupby(whole_data["year"]).sum(["Deaths"])
temperature_yearly = whole_data.groupby(whole_data["year"]).mean(["tempc"])
yearly_cancer_deaths= yearly_cancer[["Deaths"]]
temperature_yearly_change = temperature_yearly[["tempc"]]
annual_change = temperature_yearly_change.merge(yearly_cancer_deaths, on="year")
annual_change
# Out:
#          tempc  Deaths
# year
# 2000  8.333333    5922
# 2001  8.250000    6145
# 2002  7.824074    6384
# 2003  8.347222    6417
# 2004  7.689815    6196
# 2005  8.203704    6395
# 2006  8.060185    6550
# 2007  7.875000    6617
# 2008  7.189815    6719
# 2009  7.324074    6950
# 2010  7.861111    7035
# 2011  7.462963    7051
# 2012  9.064815    7306
# 2013  7.273148    7357
# 2014  7.810185    7405
# 2015  8.578704    7604
# 2016  8.490741    7928

# %%
import matplotlib.pyplot as plt


fig, ax = plt.subplots()
fig.subplots_adjust(right=0.75)
fig.set_figheight(10)
fig.set_figwidth(20)
twin1 = ax.twinx()


ax.bar(annual_change.index, annual_change["tempc"], color="r", label="Temperature",alpha=0.5 )

twin1.plot(annual_change.index, annual_change["Deaths"], label="Deaths")


ax.set_xlabel("Years")
ax.set_ylabel("Colorado Temperature")
twin1.set_ylabel("Colorado Deaths")

tkw = dict(size=4, width=1.5)
ax.tick_params(axis='x', **tkw)

plt.savefig("colorado_png")
plt.show()
