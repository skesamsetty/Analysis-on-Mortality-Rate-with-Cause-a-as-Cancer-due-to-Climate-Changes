# %%
import pandas as pd

# Dependencies and Setup
import matplotlib.pyplot as plt

# %%
mortality_rate = pd.read_csv("csv-1.csv")
temperature_rate = pd.read_csv("model_state.csv")

# %%
cancer_rate = mortality_rate.loc[mortality_rate["Cause Name"]=="Cancer"]
cancer_rate = cancer_rate.rename(columns={"Year":"year"})
cancer_rate
# Out:
#       year                 113 Cause Name Cause Name    State  Deaths  \
# 1923  2016  Malignant neoplasms (C00-C97)     Cancer  Alabama   10419
# 1924  2015  Malignant neoplasms (C00-C97)     Cancer  Alabama   10354
# 1925  2014  Malignant neoplasms (C00-C97)     Cancer  Alabama   10286
# 1926  2013  Malignant neoplasms (C00-C97)     Cancer  Alabama   10328
# 1927  2012  Malignant neoplasms (C00-C97)     Cancer  Alabama   10276
# ...    ...                            ...        ...      ...     ...
# 2854  2003  Malignant neoplasms (C00-C97)     Cancer  Wyoming     943
# 2855  2002  Malignant neoplasms (C00-C97)     Cancer  Wyoming     859
# 2856  2001  Malignant neoplasms (C00-C97)     Cancer  Wyoming     923
# 2857  2000  Malignant neoplasms (C00-C97)     Cancer  Wyoming     868
# 2858  1999  Malignant neoplasms (C00-C97)     Cancer  Wyoming     899
#
#       Age-adjusted Death Rate
# 1923                    174.0
# 1924                    175.6
# 1925                    177.6
# 1926                    182.2
# 1927                    185.2
# ...                       ...
# 2854                    188.9
# 2855                    177.1
# 2856                    194.0
# 2857                    185.5
# 2858                    195.1
#
# [936 rows x 6 columns]

# %%
cancer_rate = mortality_rate.loc[mortality_rate["Cause Name"]=="Cancer"]
cancer_rate = cancer_rate.rename(columns={"Year":"year"})
cancer_rate
# Out:
#       year                 113 Cause Name Cause Name    State  Deaths  \
# 1923  2016  Malignant neoplasms (C00-C97)     Cancer  Alabama   10419
# 1924  2015  Malignant neoplasms (C00-C97)     Cancer  Alabama   10354
# 1925  2014  Malignant neoplasms (C00-C97)     Cancer  Alabama   10286
# 1926  2013  Malignant neoplasms (C00-C97)     Cancer  Alabama   10328
# 1927  2012  Malignant neoplasms (C00-C97)     Cancer  Alabama   10276
# ...    ...                            ...        ...      ...     ...
# 2854  2003  Malignant neoplasms (C00-C97)     Cancer  Wyoming     943
# 2855  2002  Malignant neoplasms (C00-C97)     Cancer  Wyoming     859
# 2856  2001  Malignant neoplasms (C00-C97)     Cancer  Wyoming     923
# 2857  2000  Malignant neoplasms (C00-C97)     Cancer  Wyoming     868
# 2858  1999  Malignant neoplasms (C00-C97)     Cancer  Wyoming     899
#
#       Age-adjusted Death Rate
# 1923                    174.0
# 1924                    175.6
# 1925                    177.6
# 1926                    182.2
# 1927                    185.2
# ...                       ...
# 2854                    188.9
# 2855                    177.1
# 2856                    194.0
# 2857                    185.5
# 2858                    195.1
#
# [936 rows x 6 columns]

# %%
cancer_df = cancer_rate.loc[(cancer_rate["year"]>1999) & (cancer_rate["State"]=="Nevada")]
cancer_df
# Out:
#       year                 113 Cause Name Cause Name   State  Deaths  \
# 2427  2016  Malignant neoplasms (C00-C97)     Cancer  Nevada    5214
# 2428  2015  Malignant neoplasms (C00-C97)     Cancer  Nevada    5015
# 2429  2014  Malignant neoplasms (C00-C97)     Cancer  Nevada    5015
# 2430  2013  Malignant neoplasms (C00-C97)     Cancer  Nevada    4817
# 2431  2012  Malignant neoplasms (C00-C97)     Cancer  Nevada    4610
# 2432  2011  Malignant neoplasms (C00-C97)     Cancer  Nevada    4606
# 2433  2010  Malignant neoplasms (C00-C97)     Cancer  Nevada    4529
# 2434  2009  Malignant neoplasms (C00-C97)     Cancer  Nevada    4461
# 2435  2008  Malignant neoplasms (C00-C97)     Cancer  Nevada    4404
# 2436  2007  Malignant neoplasms (C00-C97)     Cancer  Nevada    4331
# 2437  2006  Malignant neoplasms (C00-C97)     Cancer  Nevada    4226
# 2438  2005  Malignant neoplasms (C00-C97)     Cancer  Nevada    4238
# 2439  2004  Malignant neoplasms (C00-C97)     Cancer  Nevada    4119
# 2440  2003  Malignant neoplasms (C00-C97)     Cancer  Nevada    4138
# 2441  2002  Malignant neoplasms (C00-C97)     Cancer  Nevada    3937
# 2442  2001  Malignant neoplasms (C00-C97)     Cancer  Nevada    3815
# 2443  2000  Malignant neoplasms (C00-C97)     Cancer  Nevada    3763
#
#       Age-adjusted Death Rate
# 2427                    157.3
# 2428                    157.2
# 2429                    164.5
# 2430                    164.8
# 2431                    163.6
# 2432                    170.2
# 2433                    174.2
# 2434                    175.3
# 2435                    179.4
# 2436                    180.8
# 2437                    184.5
# 2438                    191.0
# 2439                    191.9
# 2440                    200.2
# 2441                    201.3
# 2442                    205.1
# 2443                    213.6

# %%
climate_change = pd.read_csv("climdiv_state_year.csv")
climate_df =climate_change.loc[(climate_change["year"]>1999) & (climate_change["year"]<2017) & (climate_change["fips"]==32)]
climate_df
# Out:
#       fips  year       temp      tempc
# 3230    32  2000  51.483333  10.824074
# 3231    32  2001  51.558333  10.865741
# 3232    32  2002  50.800000  10.444444
# 3233    32  2003  52.241667  11.245370
# 3234    32  2004  50.833333  10.462963
# 3235    32  2005  50.666667  10.370370
# 3236    32  2006  50.791667  10.439815
# 3237    32  2007  51.525000  10.847222
# 3238    32  2008  50.416667  10.231481
# 3239    32  2009  50.366667  10.203704
# 3240    32  2010  50.050000  10.027778
# 3241    32  2011  49.566667   9.759259
# 3242    32  2012  52.358333  11.310185
# 3243    32  2013  50.491667  10.273148
# 3244    32  2014  53.033333  11.685185
# 3245    32  2015  52.891667  11.606481
# 3246    32  2016  51.933333  11.074074

# %%
whole_data = cancer_df.merge(climate_df , how= 'outer', on="year" )
yearly_cancer= whole_data.groupby(whole_data["year"]).sum(["Deaths"])
temperature_yearly = whole_data.groupby(whole_data["year"]).mean(["tempc"])
yearly_cancer_deaths= yearly_cancer[["Deaths"]]
temperature_yearly_change = temperature_yearly[["tempc"]]
annual_change = temperature_yearly_change.merge(yearly_cancer_deaths, on="year")
annual_change
# Out:
#           tempc  Deaths
# year
# 2000  10.824074    3763
# 2001  10.865741    3815
# 2002  10.444444    3937
# 2003  11.245370    4138
# 2004  10.462963    4119
# 2005  10.370370    4238
# 2006  10.439815    4226
# 2007  10.847222    4331
# 2008  10.231481    4404
# 2009  10.203704    4461
# 2010  10.027778    4529
# 2011   9.759259    4606
# 2012  11.310185    4610
# 2013  10.273148    4817
# 2014  11.685185    5015
# 2015  11.606481    5015
# 2016  11.074074    5214

# %%
import matplotlib.pyplot as plt


fig, ax = plt.subplots()
fig.subplots_adjust(right=0.75)
fig.set_figheight(10)
fig.set_figwidth(20)
twin1 = ax.twinx()


ax.bar(annual_change.index, annual_change["tempc"], color="r", label="Temperature",alpha=0.5 )

twin1.plot(annual_change.index, annual_change["Deaths"], label="Deaths")


ax.set_xlabel("Years")
ax.set_ylabel("Nevada Temperature")
twin1.set_ylabel("Nevada Deaths")

tkw = dict(size=4, width=1.5)
ax.tick_params(axis='x', **tkw)

plt.savefig("nevada_png")
plt.show()
